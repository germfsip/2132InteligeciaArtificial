# %% [markdown]
# # Reconocimiento de Patrones
# ## Dr. Gerardo Martinez
# ### Lección 1 - Uso de COLAB
#
# Primeramente importemos algunos paquetes

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Introducción a Pandas
# Pandas es una biblioteca para Python basada en Numpy y Matplotlib para la manipulacion y el análisis de datos. Podemos decir que da herramientas propias del lenguaje R a Python 3.
#
# Tiene dos objetos principales las Series y los DataFrame, empezemos con las series

# %%
s = pd.Series([3, -5, 7, 4], index=['a', 'b', 'c', 'd'])
print(s)
print('acceso a elemento: ', s['a'])
# Out:
# a    3
# b   -5
# c    7
# d    4
# dtype: int64
# acceso a elemento:  3

# %% [markdown]
# El objeto DataFrame es el principal objeto de la biblioteca es un arreglo bidimensional de datos mezclados con encabezado (muy similar a los DataFrame del lenguaje de programación R), acontinuación un ejemplo:

# %%
data = { 'Nombre':['Carlos', 'Julia','Fabiola', 'Ernesto'],
'edad':[28,25,56,21],
'calificación':[100,89,48,75]}
# Es muy común llamar df a nuestro DataFrame
df = pd.DataFrame(data)
print(df)
# Out:
#     Nombre  edad  calificación
# 0   Carlos    28           100
# 1    Julia    25            89
# 2  Fabiola    56            48
# 3  Ernesto    21            75

# %% [markdown]
# Para ingresar a cada dato de nuestro DataFrame, lo podemos hacer de las siguientes maneras como si fuera una matriz

# %%
print(df.iat[0,0])
print(df.iat[1,2])
print(df.at[2,'Nombre'])
# Out:
# Carlos
# 89
# Fabiola

# %% [markdown]
# Podemos escribir en el DataFrame con la misma indexación

# %%
s['b'] = 5
print('s = \n', s)
df.at[0,'Nombre'] = 'Charlie'
print('df = \n', df)
# Out:
# s =
#  a    3
# b    5
# c    7
# d    4
# dtype: int64
# df =
#      Nombre  edad  calificación
# 0  Charlie    28           100
# 1    Julia    25            89
# 2  Fabiola    56            48
# 3  Ernesto    21            75

# %% [markdown]
# Tambien podemos eliminar filas de las Series y DataFrames

# %%
s.drop(['a'])
print(s)
df.drop('calificación', axis=1)
print(df)
df = df[df.Nombre != 'Charlie']
print(df)
# Out:
# a    3
# b    5
# c    7
# d    4
# dtype: int64
#     Nombre  edad  calificación
# 0  Charlie    28           100
# 1    Julia    25            89
# 2  Fabiola    56            48
# 3  Ernesto    21            75
#     Nombre  edad  calificación
# 1    Julia    25            89
# 2  Fabiola    56            48
# 3  Ernesto    21            75

# %% [markdown]
# # Exploración de datos con Panda

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-112ba8c0-cd20-4a3e-92a9-4504d238a818" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-112ba8c0-cd20-4a3e-92a9-4504d238a818">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving countries.csv to countries.csv

# %% [markdown]
# Podemos leer el csv de la siguiente manera

# %%
df = pd.read_csv('countries.csv')

# %% [markdown]
# Cuando se sabe poco de los datos que estamos leyendo es buena costumbre hacer una exploración de los datos por ejemplo con las siguientes funciones

# %%
# Se imprimen los primeros cinco regristros
df.head()
# Out:
#        country  year         pop continent  lifeExp   gdpPercap
# 0  Afghanistan  1952   8425333.0      Asia   28.801  779.445314
# 1  Afghanistan  1957   9240934.0      Asia   30.332  820.853030
# 2  Afghanistan  1962  10267083.0      Asia   31.997  853.100710
# 3  Afghanistan  1967  11537966.0      Asia   34.020  836.197138
# 4  Afghanistan  1972  13079460.0      Asia   36.088  739.981106

# %%
# Se imprimen los últimos cinco registros
df.tail()
# Out:
#        country  year         pop continent  lifeExp   gdpPercap
# 1699  Zimbabwe  1987   9216418.0    Africa   62.351  706.157306
# 1700  Zimbabwe  1992  10704340.0    Africa   60.377  693.420786
# 1701  Zimbabwe  1997  11404948.0    Africa   46.809  792.449960
# 1702  Zimbabwe  2002  11926563.0    Africa   39.989  672.038623
# 1703  Zimbabwe  2007  12311143.0    Africa   43.487  469.709298

# %%
# Tamaño del DataFrame
print(df.shape)
# Out:
# (1704, 6)

# %%
# Información del DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   country    1704 non-null   object
#  1   year       1704 non-null   int64
#  2   pop        1704 non-null   float64
#  3   continent  1704 non-null   object
#  4   lifeExp    1704 non-null   float64
#  5   gdpPercap  1704 non-null   float64
# dtypes: float64(3), int64(1), object(2)
# memory usage: 80.0+ KB

# %%
# Mostrar columnas
df.columns
# Out:
# Index(['country', 'year', 'pop', 'continent', 'lifeExp', 'gdpPercap'], dtype='object')

# %%
# Datos estadísticos de las variables númericas
df.describe()
# Out:
#              year           pop      lifeExp      gdpPercap
# count  1704.00000  1.704000e+03  1704.000000    1704.000000
# mean   1979.50000  2.960121e+07    59.474439    7215.327081
# std      17.26533  1.061579e+08    12.917107    9857.454543
# min    1952.00000  6.001100e+04    23.599000     241.165877
# 25%    1965.75000  2.793664e+06    48.198000    1202.060309
# 50%    1979.50000  7.023596e+06    60.712500    3531.846989
# 75%    1993.25000  1.958522e+07    70.845500    9325.462346
# max    2007.00000  1.318683e+09    82.603000  113523.132900

# %%
# Crear una matrix de datos
df.values
# Out:
# array([['Afghanistan', 1952, 8425333.0, 'Asia', 28.801, 779.4453145],
#        ['Afghanistan', 1957, 9240934.0, 'Asia', 30.331999999999997,
#         820.8530296],
#        ['Afghanistan', 1962, 10267083.0, 'Asia', 31.997,
#         853.1007099999999],
#        ...,
#        ['Zimbabwe', 1997, 11404948.0, 'Africa', 46.809,
#         792.4499602999999],
#        ['Zimbabwe', 2002, 11926563.0, 'Africa', 39.989000000000004,
#         672.0386227000001],
#        ['Zimbabwe', 2007, 12311143.0, 'Africa', 43.486999999999995,
#         469.70929810000007]], dtype=object)

# %%
# Renombrar columnas
df = df.rename(columns={'gdpPercap':'gdp'})
df.head()
# Out:
#        country  year         pop continent  lifeExp         gdp
# 0  Afghanistan  1952   8425333.0      Asia   28.801  779.445314
# 1  Afghanistan  1957   9240934.0      Asia   30.332  820.853030
# 2  Afghanistan  1962  10267083.0      Asia   31.997  853.100710
# 3  Afghanistan  1967  11537966.0      Asia   34.020  836.197138
# 4  Afghanistan  1972  13079460.0      Asia   36.088  739.981106

# %%
# Regresar una columna como Series
s1 = df['country']
s2 = df.country
print(s1)
print(s2)
# Out:
# 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
#            ...
# 1699       Zimbabwe
# 1700       Zimbabwe
# 1701       Zimbabwe
# 1702       Zimbabwe
# 1703       Zimbabwe
# Name: country, Length: 1704, dtype: object
# 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
#            ...
# 1699       Zimbabwe
# 1700       Zimbabwe
# 1701       Zimbabwe
# 1702       Zimbabwe
# 1703       Zimbabwe
# Name: country, Length: 1704, dtype: object

# %%
# Regresar una columna como un DataFrame
df2 = df[['country']]
print(df2.head())
# Out:
#        country
# 0  Afghanistan
# 1  Afghanistan
# 2  Afghanistan
# 3  Afghanistan
# 4  Afghanistan

# %%
# Cambiar todos los elementos con cierto valor
df2 = df.replace(1952,'one')
df2.head()
# Out:
#        country  year         pop continent  lifeExp         gdp
# 0  Afghanistan   one   8425333.0      Asia   28.801  779.445314
# 1  Afghanistan  1957   9240934.0      Asia   30.332  820.853030
# 2  Afghanistan  1962  10267083.0      Asia   31.997  853.100710
# 3  Afghanistan  1967  11537966.0      Asia   34.020  836.197138
# 4  Afghanistan  1972  13079460.0      Asia   36.088  739.981106

# %%
# Filtrado por columna
df[df.country == 'Mexico']
# Out:
#     country  year          pop continent  lifeExp           gdp
# 984  Mexico  1952   30144317.0  Americas   50.789   3478.125529
# 985  Mexico  1957   35015548.0  Americas   55.190   4131.546641
# 986  Mexico  1962   41121485.0  Americas   58.299   4581.609385
# 987  Mexico  1967   47995559.0  Americas   60.110   5754.733883
# 988  Mexico  1972   55984294.0  Americas   62.361   6809.406690
# 989  Mexico  1977   63759976.0  Americas   65.032   7674.929108
# 990  Mexico  1982   71640904.0  Americas   67.405   9611.147541
# 991  Mexico  1987   80122492.0  Americas   69.498   8688.156003
# 992  Mexico  1992   88111030.0  Americas   71.455   9472.384295
# 993  Mexico  1997   95895146.0  Americas   73.670   9767.297530
# 994  Mexico  2002  102479927.0  Americas   74.902  10742.440530
# 995  Mexico  2007  108700891.0  Americas   76.195  11977.574960

# %%
#Filtrado con reindexado automático
df_mex = df[df.country == 'Mexico'][df.year >= 1977][df.lifeExp < 70]
print(df_mex)
# Out:
#     country  year         pop continent  lifeExp          gdp
# 989  Mexico  1977  63759976.0  Americas   65.032  7674.929108
# 990  Mexico  1982  71640904.0  Americas   67.405  9611.147541
# 991  Mexico  1987  80122492.0  Americas   69.498  8688.156003
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %%
df_mex = df_mex.reset_index()
df_mex = df_mex.drop('index', axis=1)
print(df_mex)
# Out:
#   country  year         pop continent  lifeExp          gdp
# 0  Mexico  1977  63759976.0  Americas   65.032  7674.929108
# 1  Mexico  1982  71640904.0  Americas   67.405  9611.147541
# 2  Mexico  1987  80122492.0  Americas   69.498  8688.156003

# %%
# Histograma de las variables numericas
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f05eccb1090>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f05eca9d090>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f05e5dd12d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f05e5d84950>]],
#       dtype=object)

# %%
df[df.country == 'Mexico'].plot(x='year',y='gdp')

# %%
pd.plotting.scatter_matrix(df)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f05e5737410>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f05e56e7490>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f05e571cb10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f05e56dc1d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f05e5694850>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f05e564aed0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f05e560a610>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f05e55c1bd0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f05e55c1c10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f05e55853d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f05e54e7ad0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f05e54b3690>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f05e5469d10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f05e542b3d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f05e5460a50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f05e53a5110>]],
#       dtype=object)

# %%
# Grafica de México
pd.plotting.scatter_matrix(df[df.country == 'Mexico'])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f05e52f9f50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f05e520a850>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f05e51add10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f05e51702d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f05e5126850>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f05e5159dd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f05e511b410>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f05e50d18d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f05e50d1910>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f05e5089f90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f05e4ffe9d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f05e4fb6f50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f05e4f78510>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f05e4f2ea90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f05e4ee5fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f05e4ea65d0>]],
#       dtype=object)
