# %% [markdown]
# <a href="https://colab.research.google.com/github/germfsip/2132InteligeciaArtificial/blob/main/Laboratorio3IA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Realiza una red neuronal que pueda indicar si los siguientes casos de prueba es hombre o mujer
#
#
# *   174 cm  ->   75 kg
# *   165 cm  -> 53 kg
# *   Proponga una talla y peso
#
# Con base en el siguiente entrenamiento
# ![red.png](data:image/png;base64,...)

# %%
datos = [[170,56,1],
              [172,63,0],
              [160,50,1],
              [170,63,0],
              [174,66,0],
              [158,55,1],
              [183,80,0],
              [182,70,0],
              [165,54,1]]
